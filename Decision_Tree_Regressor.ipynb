# %% [markdown]
# <a href="https://colab.research.google.com/github/Uwais-ur-Rehman/ML-Project/blob/main/Decision_Tree_Regressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Salary Data.csv')
df.sample(2)
# Out:
#       Age  Gender Education Level               Job Title  \
# 308  42.0  Female      Bachelor's  Senior Project Manager
# 275  38.0  Female      Bachelor's  Senior Project Manager
#
#      Years of Experience    Salary
# 308                 12.0  120000.0
# 275                  9.0  120000.0

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
x=df.drop(columns=['Gender','Education Level','Job Title','Salary'])
y=df['Salary']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
model.score(x_train,y_train)*100
# Out:
# 94.02675651289677

# %%
model.score(x_test,y_test)*100
# Out:
# 77.0121656129754

# %%
model.predict([[22,43]])
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([72500.])

# %%
model.predict([[47,19]])
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([174000.])

# %%
x.sample(3)
# Out:
#       Age  Years of Experience
# 259  29.0                  1.5
# 26   37.0                 11.0
# 45   28.0                  2.0

# %%
model1=DecisionTreeRegressor(max_depth=4)
model1.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=4)

# %%
model.score(x_train,y_train)*100
# Out:
# 94.02675651289677

# %%
model.score(x_test,y_test)*100
# Out:
# 77.0121656129754

# %%
sns.pairplot(data=df)
plt.show()

# %%
from sklearn.tree import plot_tree
plot_tree(model,feature_names=x.columns)
plt.show()

# %%
for i in range(1,20):
  model=DecisionTreeRegressor(max_depth=i)
  model.fit(x_train,y_train)
  print(i,model.score(x_train,y_train)*100,model.score(x_test,y_test)*100,model.score(x_train,y_train)*100-model.score(x_test,y_test)*100)
# Out:
# 1 67.70999352748723 52.47664030584328 15.233353221643945
# 2 86.07169993157132 78.02755241538657 8.04414751618475
# 3 89.16465014678626 81.69874977268394 7.465900374102318
# 4 90.77681758170148 76.89260783753215 13.884209744169326
# 5 91.74246710322744 78.50965227286433 13.232814830363111
# 6 92.1067848899131 77.47651448086599 14.630270409047114
# 7 92.62079518786854 76.4324794540262 16.188315733842344
# 8 92.94778721499293 76.99730208946227 15.950485125530662
# 9 93.47883324892042 76.61789294524738 16.860940303673047
# 10 93.69506154768324 76.67432451653244 17.0207370311508
# 11 93.99245424315646 76.73302976362568 17.25942447953078
# 12 94.02675651289677 77.0121656129754 17.014590899921373
# 13 94.02675651289677 77.0121656129754 17.014590899921373
# 14 94.02675651289677 77.0121656129754 17.014590899921373
# 15 94.02675651289677 77.0121656129754 17.014590899921373
# 16 94.02675651289677 77.0121656129754 17.014590899921373
# 17 94.02675651289677 77.0121656129754 17.014590899921373
# ...
